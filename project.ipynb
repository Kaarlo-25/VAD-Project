# %% [markdown]
# # NYC TAXIS VISUALIZATION

# %%
import pandas as pd
import folium
import geopandas as gpd
import geodatasets

# %%
data_1 = pd.read_csv("C:\\Users\\valko\\OneDrive\\Documentos\\data\\yellow_tripdata_2016-01.csv")
data_1
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 1                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 2                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 3                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 4                2  2016-01-01 00:00:00   2016-01-01 00:00:00
# ...            ...                  ...                   ...
# 10906853         2  2016-01-31 23:30:32   2016-01-31 23:38:18
# 10906854         1  2016-01-05 00:15:55   2016-01-05 00:16:06
# 10906855         1  2016-01-05 06:12:46   2016-03-19 20:45:50
# 10906856         1  2016-01-05 06:21:44   2016-03-28 12:54:26
# 10906857         1  2016-01-05 06:15:21   2016-01-05 06:15:36
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       2           1.10        -73.990372        40.734695
# ...

# %%
data_sample = data_1.sample(n=1000, random_state=42)  # `random_state` asegura que siempre obtengas la misma muestra
data_sample.head()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3801703         2  2016-01-25 15:32:01   2016-01-25 16:00:16                1
# 1620092         1  2016-01-08 07:09:51   2016-01-08 08:21:55                1
# 8460962         1  2016-01-21 09:30:24   2016-01-21 09:37:07                1
# 4339863         2  2016-01-14 14:25:29   2016-01-14 14:38:24                1
# 1143050         1  2016-01-05 09:44:05   2016-01-05 09:56:49                1
#
#          trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 3801703           2.47        -73.974640        40.793400           1
# 1620092          18.40        -73.790215        40.647221           2
# 8460962           0.90        -73.982170        40.768208           1
# 4339863           2.04        -73.978729        40.762302           1
# 1143050           1.70        -73.996086        40.743584           1
#
# ...

# %%
nyc_map = gpd.read_file(geodatasets.get_path("geoda.nyc"))

# Asignar CRS si no está definido
if nyc_map.crs is None:
    nyc_map.set_crs(epsg=4326, inplace=True)

# Crear el mapa centrado en NYC
m = folium.Map(
    location=[40.7128, -74.0060],
    zoom_start=11,
    tiles="CartoDB Positron",
    min_zoom=10,
)

for _, row in data_sample.iterrows():
    folium.CircleMarker(
        location=[row["pickup_latitude"], row["pickup_longitude"]],
        radius=3,  # Tamaño del punto
        color="green",
        fill=True,
        fill_color="green",
        fill_opacity=0.7
    ).add_to(m)

m  # Mostrar el mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
data_2 = pd.read_csv("C:\\Users\\valko\\OneDrive\\Documentos\\data\\yellow_tripdata_2016-02.csv")
data_2
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2016-02-25 17:24:20   2016-02-25 17:27:20
# 1                2  2016-02-25 23:10:50   2016-02-25 23:31:50
# 2                2  2016-02-01 00:00:01   2016-02-01 00:10:52
# 3                1  2016-02-01 00:00:04   2016-02-01 00:05:16
# 4                2  2016-02-01 00:00:05   2016-02-01 00:20:59
# ...            ...                  ...                   ...
# 11382044         1  2016-02-13 22:38:51   2016-06-24 12:30:49
# 11382045         1  2016-02-13 22:39:42   2016-06-23 02:10:11
# 11382046         1  2016-02-13 22:39:49   2016-06-25 12:32:54
# 11382047         1  2016-02-13 22:42:34   2016-06-26 11:55:57
# 11382048         1  2016-02-13 22:48:20   2016-06-22 20:30:05
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       2           0.70        -73.947250        40.763771
# ...

# %%
data_3 = pd.read_csv("C:\\Users\\valko\\OneDrive\\Documentos\\data\\yellow_tripdata_2016-03.csv")
data_3
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                1  2016-03-01 00:00:00   2016-03-01 00:07:55
# 1                1  2016-03-01 00:00:00   2016-03-01 00:11:06
# 2                2  2016-03-01 00:00:00   2016-03-01 00:31:06
# 3                2  2016-03-01 00:00:00   2016-03-01 00:00:00
# 4                2  2016-03-01 00:00:00   2016-03-01 00:00:00
# ...            ...                  ...                   ...
# 12210947         1  2016-03-31 16:34:36   2016-03-31 16:34:36
# 12210948         1  2016-03-26 03:02:32   2016-06-14 18:47:55
# 12210949         1  2016-03-20 08:43:59   2016-06-27 15:05:01
# 12210950         1  2016-03-20 08:49:47   2016-06-28 19:11:27
# 12210951         1  2016-03-20 08:50:24   2016-06-29 15:58:16
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       1           2.50        -73.976746        40.765152
# ...
